# %%
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data
y = iris.target

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Try to find original plot

# %%
import pandas as pd

# %%
iris_df = pd.DataFrame(data=X, columns=iris.feature_names)
iris_df['species'] = iris.target_names[y]

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(iris_df, c=y, figsize=(10, 10), marker='o')
plt.show()

# %% [markdown]
# Try to plot pca

# %%
import numpy as np

covariance_matrix = np.cov(X_scaled.T)

# %%
eigenvalues, eigenvectors = np.linalg.eig(covariance_matrix)

# %%
eigenvectors_sorted = eigenvectors[:, np.argsort(eigenvalues)[::-1]]

# %%
k = 2
eigenvectors_subset = eigenvectors_sorted[:, :k]

# %%
X_pca = X_scaled.dot(eigenvectors_subset)

# %%
import matplotlib.pyplot as plt

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
